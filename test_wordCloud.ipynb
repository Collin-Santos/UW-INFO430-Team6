# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_csv("tweets.csv")
df.head()
# Out:
#                     id   user_id  \
# 0  1391026351960993793  17351972
# 1  1391034310363426817  50883209
# 2  1391056139400404997  16252784
# 3  1391060327224250368  16252784
# 4  1391060329803698176  16252784
#
#                                              content creation_date
# 0  Recreating the 2006 makeup.\n\nThe @Jumpman23 ...    2021-05-08
# 1  100 POLES 👑 @LewisHamilton \n#OnlySeeGreat htt...    2021-05-08
# 2             Morning workouts are our one and only.    2021-05-08
# 3  How do you become a runner? You run. But first...    2021-05-08
# 4  Believe that you don't have to be good at runn...    2021-05-08

# %%
text = df['content']
text.head()
# Out:
# 0    Recreating the 2006 makeup.\n\nThe @Jumpman23 ...
# 1    100 POLES 👑 @LewisHamilton \n#OnlySeeGreat htt...
# 2               Morning workouts are our one and only.
# 3    How do you become a runner? You run. But first...
# 4    Believe that you don't have to be good at runn...
# Name: content, dtype: object

# %%
comment_word = ''
stopwords = set(STOPWORDS)

# %%
for val in df.content: 
    val = str(val)
    tokens = val.split()

    #tokens = re.sub(r'\W+', '', val).lower()
    
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
        tokens[i] = tokens[i].replace("https","")
        tokens[i] = tokens[i].replace("t","")
        tokens[i] = tokens[i].replace("co","")
        #tokens[i] = tokens[i].replace("s","")
        #tokens[i] = tokens[i].replace("et","")
    #print(tokens)
    comment_word += " ".join(tokens)+" "
    print(tokens)
# Out:
# ['recreaing', 'he', '2006', 'makeup.', 'he', '@jumpman23', 'air', 'jordan', '7', "'flin'", 'draw', 'opens', 'a', '10am', 'e', '🇺🇸', '://./vnz3ik7vf', '://./rbgbmyrdmv']
# ['100', 'poles', '👑', '@lewishamilon', '#onlyseegrea', '://./ckuppcwmcl']
# ['morning', 'workous', 'are', 'our', 'one', 'and', 'only.']
# ['how', 'do', 'you', 'beme', 'a', 'runner?', 'you', 'run.', 'bu', 'firs:', '://./crdyrcma1b']
# ['believe', 'ha', 'you', "don'", 'have', 'o', 'be', 'good', 'a', 'running', 'o', 'sar.']
# ['remember', 'ha', 'disance', "doesn'", 'maer.']
# ['know', 'ha', 'runners', "aren'", 'prone', 'o', 'errible', 'knees.']
# ['celebrae', 'he', 'lile', 'runs.']
# ['se', 'goals', 'o', 'give', 'your', 'run', 'more', 'purpose.']
# ['lisen', 'o', 'your', 'body', 'bu', 'challenge', 'yourself.']
# ['wach', 'he', 'video', 'for', 'pre', 'and', 'pos-run', 'revery', 'ips', '://./crdyrcma1b']
# ...

# %%
wordCloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_word)

# %%
plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordCloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
#plt.show()
plt.savefig('wordCloud.png')
